# %%
import itertools


example = """3-5
10-14
16-20
12-18

1
5
8
11
17
32"""


with open('five.txt', 'r', encoding='utf-8') as file:
    data = file.read()

# data = data.split('\n\n')[0].split('\n')
data


def format(data):
    data = data.split('\n\n')
    data = [i.split('\n')for i in data]
    #data[0] = list(itertools.chain(*[list(range(int(i.split('-')[0]),int(i.split('-')[1])+1))for i in data[0]]))
    #data[0] = [list(range(int(i.split('-')[0]),int(i.split('-')[1])+1))for i in data[0]]
    data[1] = [int(i)for i in data[1]]
    return data

# %%
formated_data = format(data)
data = formated_data[0]
data = [i.split('-')for i in data]
data = [[int(i)for i in j]for j in data]
data
# Out:
# [[318557298670257, 320203701512914],
#  [257988476988123, 258475833446953],
#  [239506567904360, 239506567904360],
#  [159092054628984, 160660945293660],
#  [33508345158641, 33508345158641],
#  [535574085704173, 542529962005080],
#  [259223906521657, 259570839796231],
#  [107124201554838, 107491094003520],
#  [408597058494409, 408747547856220],
#  [204209427005525, 210465015733810],
#  [191953754819394, 199391870677509],
#  [184436261451506, 184436261451506],
#  [121406307434528, 126395493108292],
#  [112658959754792, 119541264499023],
#  [256813240979222, 257191182675058],
#  [332175956014557, 336020407709884],
#  [464523147874452, 468780439477643],
#  [232531131562106, 239506567904359],
#  [342509931670831, 347620075555999],
#  [426811759586883, 431461654697663],
#  [439839000198979, 440189239373558],
#  [403011203089000, 403697076743498],
#  [448512942059195, 448512942059195],
#  [156253640950711, 157569806110925],
#  [251421563132760, 251960455619173],
# ...

# %%
550000000 in range(500000000,500000000000000)
# Out:
# True

# %%
id_mini, id_maxi = None, None

id_mini ==  None and  id_maxi == None
# Out:
# True

# %%
# create a list of odd numbers
odd_n = [1,3,5,7,9]

# '21' is inserted at index 3 (4th position)
odd_n.insert(3, 21)


print('List of odd #:', odd_n)
# Out:
# List of odd #: [1, 3, 5, 21, 7, 9]

# %%
q = ['a', 'e','g']
q.insert(0,'z')
q
# Out:
# ['z', 'a', 'e', 'g']

# %%
a,b =range(3,8), range(6,9)
if 8 > 9:
    suppr(b)
elif 8 in b:
    merge

# %%
l=[]
for rangee in data:
    mini, maxi = rangee[0], rangee[1]
    if l==[]:
        l.append(rangee)
        break
    for index, stored_range in enumerate(l):
        if maxi < min(stored_range):
            l.insert(0, range(mini,maxi))
        elif maxi < max(stored_range):
            if mini < min(stored_range):
                l[index] = range(mini, max(stored_range))

        temp_l = []
        for 




METTRE UN UPDATE POUR LES RANGES QUI SE RECOUPENT

# %%
dico = {}

for index, id_range in enumerate(data):
    if len(dico) == 0:
        dico[index] = range(id_range[0], id_range[1])
        break
    id_mini, id_maxi = None, None
    for i in dico:
        if id_mini in dico[i]:
            id_mini = i
        if id_maxi in dico[i]:
            id_maxi = i
# Out:
# {318557298670257: 320203701512914,
#  257988476988123: 258475833446953,
#  239506567904360: 239506567904360,
#  159092054628984: 160660945293660,
#  33508345158641: 33508345158641,
#  535574085704173: 542529962005080,
#  259223906521657: 259570839796231,
#  107124201554838: 107491094003520,
#  408597058494409: 408747547856220,
#  204209427005525: 210465015733810,
#  191953754819394: 197190347597413,
#  184436261451506: 188838397899786,
#  121406307434528: 126395493108292,
#  112658959754792: 119541264499023,
#  256813240979222: 257508907299303,
#  332175956014557: 340193057113421,
#  464523147874452: 468780439477643,
#  232531131562106: 239506567904359,
#  342509931670831: 347620075555999,
#  426811759586883: 431461654697663,
#  439839000198979: 440189239373558,
#  403011203089000: 403255095687272,
#  448512942059195: 448512942059195,
#  156253640950711: 157569806110925,
#  251421563132760: 251960455619173,
#  398112870005920: 400840791809897,
#  100861951548231: 101340153826899,
# ...

# %%
l = []
for i in formated_data[0]:
    i = i.split('-')
    l+=list(range(int(i[0]), int(i[1])+1))
    l = list(set(l))
    print(l)
l

# %%
len(range(1,5))

# %%
formated_data = format(data)
ids = formated_data[1]
count = 0
for id in ids:
    for rangee in formated_data[0]:
        splited_range = rangee.split('-')
        if id in range(int(splited_range[0]), int(splited_range[1])+1):
            count +=1
            print(id)
            break
count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 formated_data = format(data)
#       2 ids = formated_data[1]
#       3 count = 0
#
# Cell In[3], line 21, in format(data)
#      20 def format(data):
# ---> 21     data = data.split('\n\n')
#      22     data = [i.split('\n')for i in data]
#      23     #data[0] = list(itertools.chain(*[list(range(int(i.split('-')[0]),int(i.split('-')[1])+1))for i in data[0]]))
#      24     #data[0] = [list(range(int(i.split('-')[0]),int(i.split('-')[1])+1))for i in data[0]]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
def find_fresh_ids(data):
    ranges = data[0]
    ids = data[1]
    fresh_ids = [id for id in ids if id in ranges]
    return len(fresh_ids)

# %%
find_fresh_ids(format(example))
# Out:
# 0
